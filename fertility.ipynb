# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score,mean_squared_error
from math import sqrt
# %matplotlib inline

# %%
data = pd.read_csv('data.csv')

# %%
data.shape
# Out:
# (100, 17)

# %%
data_cpy = data.copy()
data_cpy1=data.copy()

# %%
data.head(10)
# Out:
#      pH    EC    OC    OM    N     P    K    Zn   Fe    Cu   Mn  Sand  Silt  \
# 0  7.74  0.40  0.01  0.01   75  20.0  279  0.48  6.4  0.21  4.7  84.3   6.8
# 1  9.02  0.31  0.02  0.03   85  15.7  247  0.27  6.4  0.16  5.6  90.4   3.9
# 2  7.80  0.17  0.02  0.03   77  35.6  265  0.46  6.2  0.51  6.1  84.5   6.9
# 3  8.36  0.02  0.03  0.05  106   6.4  127  0.50  3.1  0.28  2.3  93.9   1.7
# 4  8.36  1.08  0.03  0.05   96  10.5   96  0.31  3.2  0.23  4.1  91.5   4.1
# 5  8.36  0.73  0.03  0.05  151  10.5  230  0.38  2.5  0.37  4.2  94.2   1.5
# 6  7.69  0.11  0.04  0.06  112   8.0  120  0.51  3.1  0.32  1.2  96.2   1.7
# 7  8.39  0.06  0.04  0.06  125  18.5  145  0.67  2.8  0.18  1.8  87.9   4.8
# 8  7.87  0.43  0.04  0.06  112  27.0  333  0.75  3.9  0.54  1.8  80.5   5.7
# 9  8.09  0.62  0.04  0.06   89  28.2  146  0.53  3.8  0.71  3.9  80.2   9.5
#
#    Clay  CaCO3    CEC       Output
# 0   8.9   6.72   7.81      Fertile
# 1   5.7   4.61   7.19      Fertile
# ...

# %%
data['Output'].unique()
# Out:
# array(['Fertile', 'Non Fertile'], dtype=object)

# %%
data['Output'].nunique()
# Out:
# 2

# %%
#Nrml

# %%
data['pH']=data['pH'].astype('int64')
data['EC']=data['EC'].astype('int64')
data['OC']=data['OC'].astype('int64')
data['OM']=data['OM'].astype('int64')
data['N']=data['N'].astype('int64')
data['P']=data['P'].astype('int64')
data['K']=data['K'].astype('int64')
data['Zn']=data['Zn'].astype('int64')
data['Fe']=data['Fe'].astype('int64')
data['Cu']=data['Cu'].astype('int64')
data['Mn']=data['Mn'].astype('int64')
data['Sand']=data['Sand'].astype('int64')
data['CaCO3']=data['CaCO3'].astype('int64')
data['CaCO3']=data['CaCO3'].astype('int64')

# %%
cnames = ['pH','EC','OC','OM','N','P','K','Zn','Fe','Cu','Mn','Sand','CaCO3','CEC',]

# %%
cnames
# Out:
# ['pH',
#  'EC',
#  'OC',
#  'OM',
#  'N',
#  'P',
#  'K',
#  'Zn',
#  'Fe',
#  'Cu',
#  'Mn',
#  'Sand',
#  'CaCO3',
#  'CEC']

# %%
for i in cnames:
    print(i)
    data_cpy1[i]=(data[i]-min(data[i]))/max(data[i]-min(data[i]))
# Out:
# pH
# EC
# OC
# OM
# N
# P
# K
# Zn
# Fe
# Cu
# Mn
# Sand
# CaCO3
# CEC

# %%
data_cpy1
# Out:
#           pH   EC  OC   OM         N         P         K   Zn     Fe  Cu  \
# 0   0.333333  0.0 NaN  0.0  0.000000  0.558824  0.509756  0.0  0.625 NaN
# 1   1.000000  0.0 NaN  0.0  0.049261  0.411765  0.431707  0.0  0.625 NaN
# 2   0.333333  0.0 NaN  0.0  0.009852  1.000000  0.475610  0.0  0.625 NaN
# 3   0.666667  0.0 NaN  0.0  0.152709  0.147059  0.139024  0.0  0.250 NaN
# 4   0.666667  1.0 NaN  0.0  0.103448  0.264706  0.063415  0.0  0.250 NaN
# ..       ...  ...  ..  ...       ...       ...       ...  ...    ...  ..
# 95  1.000000  0.0 NaN  1.0  1.000000  0.235294  0.231707  0.0  0.875 NaN
# 96  0.333333  0.0 NaN  1.0  0.970443  0.235294  0.168293  0.0  0.125 NaN
# 97  0.666667  0.0 NaN  1.0  0.995074  0.294118  0.473171  0.0  0.750 NaN
# 98  0.666667  0.0 NaN  1.0  0.935961  0.088235  0.519512  0.0  0.250 NaN
# 99  0.333333  0.0 NaN  1.0  0.995074  0.911765  0.417073  0.0  0.875 NaN
#
#           Mn      Sand  Silt  Clay   CaCO3       CEC       Output
# ...

# %%
data_cpy
# Out:
#       pH    EC    OC    OM    N     P    K    Zn   Fe    Cu   Mn  Sand  Silt  \
# 0   7.74  0.40  0.01  0.01   75  20.0  279  0.48  6.4  0.21  4.7  84.3   6.8
# 1   9.02  0.31  0.02  0.03   85  15.7  247  0.27  6.4  0.16  5.6  90.4   3.9
# 2   7.80  0.17  0.02  0.03   77  35.6  265  0.46  6.2  0.51  6.1  84.5   6.9
# 3   8.36  0.02  0.03  0.05  106   6.4  127  0.50  3.1  0.28  2.3  93.9   1.7
# 4   8.36  1.08  0.03  0.05   96  10.5   96  0.31  3.2  0.23  4.1  91.5   4.1
# ..   ...   ...   ...   ...  ...   ...  ...   ...  ...   ...  ...   ...   ...
# 95  9.21  0.14  0.62  1.06  278   9.8  165  0.18  8.6  0.57  5.8  88.2   2.4
# 96  7.50  0.22  0.68  1.17  272   9.5  139  0.72  2.6  0.12  1.8  95.4   1.4
# 97  8.26  0.25  0.71  1.22  277  11.5  264  0.36  7.6  0.07  0.8  90.7   2.5
# 98  8.12  0.14  0.73  1.25  265   4.6  283  0.38  3.7  0.18  0.8  86.0   6.7
# 99  7.31  0.46  0.74  1.27  277  32.4  241  0.27  8.2  0.23  4.2  80.5   6.8
#
#     Clay  CaCO3    CEC       Output
# ...

# %%
for i in cnames:
    print(i)
    
    data_cpy[i] = data_cpy[i]-(data_cpy[i].mean())/data_cpy[i].std()
# Out:
# pH
# EC
# OC
# OM
# N
# P
# K
# Zn
# Fe
# Cu
# Mn
# Sand
# CaCO3
# CEC

# %%
data_cpy
# Out:
#           pH        EC        OC        OM           N          P           K  \
# 0  -7.980106 -0.694275 -1.134959 -1.117432   72.134599  18.427437  276.538027
# 1  -6.700106 -0.784275 -1.124959 -1.097432   82.134599  14.127437  244.538027
# 2  -7.920106 -0.924275 -1.124959 -1.097432   74.134599  34.027437  262.538027
# 3  -7.360106 -1.074275 -1.114959 -1.077432  103.134599   4.827437  124.538027
# 4  -7.360106 -0.014275 -1.114959 -1.077432   93.134599   8.927437   93.538027
# ..       ...       ...       ...       ...         ...        ...         ...
# 95 -6.510106 -0.954275 -0.524959 -0.067432  275.134599   8.227437  162.538027
# 96 -8.220106 -0.874275 -0.464959  0.042568  269.134599   7.927437  136.538027
# 97 -7.460106 -0.844275 -0.434959  0.092568  274.134599   9.927437  261.538027
# 98 -7.600106 -0.954275 -0.414959  0.122568  262.134599   3.027437  280.538027
# 99 -8.410106 -0.634275 -0.404959  0.142568  274.134599  30.827437  238.538027
#
# ...

# %%
data
# Out:
#     pH  EC  OC  OM    N   P    K  Zn  Fe  Cu  Mn  Sand  Silt  Clay  CaCO3  \
# 0    7   0   0   0   75  20  279   0   6   0   4    84   6.8   8.9      6
# 1    9   0   0   0   85  15  247   0   6   0   5    90   3.9   5.7      4
# 2    7   0   0   0   77  35  265   0   6   0   6    84   6.9   8.6      1
# 3    8   0   0   0  106   6  127   0   3   0   2    93   1.7   4.4      0
# 4    8   1   0   0   96  10   96   0   3   0   4    91   4.1   4.4      9
# ..  ..  ..  ..  ..  ...  ..  ...  ..  ..  ..  ..   ...   ...   ...    ...
# 95   9   0   0   1  278   9  165   0   8   0   5    88   2.4   9.4      4
# 96   7   0   0   1  272   9  139   0   2   0   1    95   1.4   3.2      0
# 97   8   0   0   1  277  11  264   0   7   0   0    90   2.5   6.8      3
# 98   8   0   0   1  265   4  283   0   3   0   0    86   6.7   7.3      0
# 99   7   0   0   1  277  32  241   0   8   0   4    80   6.8  12.7      4
#
#       CEC       Output
# 0    7.81      Fertile
# 1    7.19      Fertile
# ...

# %%
dep = data['count']0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'count'
#
# The above exception was the direct cause of the following exception:
#
# ...
